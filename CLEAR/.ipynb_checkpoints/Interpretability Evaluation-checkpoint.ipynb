# %%
import CLEAR

from int_met import * #(fromm https://github.com/Mo-youssef/interpretability/blob/master/int_met.py)

# %%
exp1_coefs = CLEAR.run_Clear('BreastC',1)

exp2_coefs = CLEAR.run_Clear('BreastC',1)
# Out:
# Pre-processing
#
# WARNING: Entity <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x00000158E17034C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x00000158E17034C8>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
i = calc_identity(exp1_coefs, exp2_coefs)
print("Identity Metric Scores for CLEAR: ", i)
# Out:
# Identity Metric Scores for CLEAR:  (0.0, 15, 15)
